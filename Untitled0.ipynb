# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Variables,Data Types, Operators

# %%
# calculate area of a triangle

h = 20
b = 10
area = 1/2 * b * h
print(area)
# Out:
# 100.0

# %% [markdown]
# understanded f-string

# %%
# calculate area of a triangle

h = 20
b = 10
print("The area is:",1/2 * b* h)
print(f"The area is:{1/2 * b* h}")
# Out:
# The area is: 100.0
# The area is:100.0

# %% [markdown]
# Lists & Indexing

# %%
marks = [70, 85, 90, 60]
print(marks)
# Out:
# [70, 85, 90, 60]

# %% [markdown]
# Lists & Indexing

# %%
marks = [70, 85, 90, 60]
print(marks)
print(marks[0])  #first element
print(marks[-1]) #last element
# Out:
# [70, 85, 90, 60]
# 70
# 60

# %% [markdown]
# Conditional Stastement (if-else, if-elif-else,nested)what is indentation?important proper spacing

# %%
# Largest among three numbers
a,b,c=10, 20,30

if(a>b and a>c):
  print("a is largest")
   elif(b>a and b>c):
    print("b is largest")
 else:
   print("c is largest")
# Out:
#   File "<tokenize>", line 8
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# Let's Understand Modules
# A python file

# %%
#import current date & time

import datetime

a = datetime.datetime.now()
print(f"The current date & time is: {a}")
# Out:
# The current date & time is: 2026-02-18 06:36:21.072802

# %% [markdown]
# Loops: for, while

# %%
# print 1-10 using for loop

for i in range(10,3,-2):
  print(i)
# Out:
# 10
# 8
# 6
# 4

# %%
# print 1-10 using for loop
for i in range(10,3,-2):
  print(i)
  for i in range(10,3,-2):
    print(i)
    for i in range(10,3,-2):
      print(i)
# Out:
# 10
# 10
# 10
# 8
# 6
# 4
# 8
# 10
# 8
# 6
# 4
# 6
# 10
# 8
# 6
# 4
# 4
# 10
# 8
# 6
# 4
# 8
# 10
# 10
# 8
# 6
# 4
# 8
# 10
# 8
# 6
# 4
# 6
# 10
# 8
# 6
# 4
# 4
# 10
# 8
# 6
# 4
# 6
# 10
# 10
# 8
# 6
# 4
# 8
# 10
# 8
# 6
# 4
# 6
# 10
# 8
# 6
# 4
# 4
# 10
# 8
# 6
# 4
# 4
# 10
# 10
# 8
# 6
# 4
# 8
# 10
# 8
# 6
# 4
# 6
# 10
# 8
# 6
# 4
# 4
# 10
# 8
# 6
# 4

# %%
# print 1-10 using for loop
for i in range(1,11):
  print(i)

  # print even number from 1-10
for i in range(2,11,2):
  print(i)

  # print odd number from 3-20
for i in range(3,21,2):
  print(i)

  # print reverse number (10-1)
for i in range(10,3,-2):
  print(i)

  #try to understand Nested Loops & Importance of Indentation

for i in range(10,3,-2):
  print(i)

# %% [markdown]
# String & it methods

# %%
name = "Ardent"

print(name)
print(name.upper())
print(name.lower())
print(name.index("A"))
# Out:
# Ardent
# ARDENT
# ardent
# 0

# %% [markdown]
# **Function**
# user Defined Function: AS a Developer What you're making in build function

# %%
#function to calculate average
def avg(phy, che, math):
  return (phy+che+math)/3
print(avg(50,60,80))

# for perfection: u should know fuction defination, calling function , parameter, arguments
# Out:
# 63.333333333333336
